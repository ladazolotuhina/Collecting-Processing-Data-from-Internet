# %% [markdown]
# #### 1. Посмотреть документацию к API GitHub, разобраться как вывести список репозиториев для конкретного пользователя, сохранить JSON-вывод в файле *.json.

# %%
import requests
from pprint import pprint
import json

# %%
url = 'https://api.github.com/users/ladazolotuhina/repos'
user = "ladazolotuhina"

# %%
Res = requests.get(url)
print(Res.status_code)
pprint(Res.json())
# Out:
# 200
# [{'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/ladazolotuhina/-LIBRARIES-Python-/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/ladazolotuhina/-LIBRARIES-Python-/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/ladazolotuhina/-LIBRARIES-Python-/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/ladazolotuhina/-LIBRARIES-Python-/branches{/branch}',
#   'clone_url': 'https://github.com/ladazolotuhina/-LIBRARIES-Python-.git',
#   'collaborators_url': 'https://api.github.com/repos/ladazolotuhina/-LIBRARIES-Python-/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/ladazolotuhina/-LIBRARIES-Python-/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/ladazolotuhina/-LIBRARIES-Python-/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/ladazolotuhina/-LIBRARIES-Python-/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/ladazolotuhina/-LIBRARIES-Python-/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/ladazolotuhina/-LIBRARIES-Python-/contributors',
#   'created_at': '2022-05-01T17:36:52Z',
#   'default_branch': 'main',
#   'deployments_url': 'https://api.github.com/repos/ladazolotuhina/-LIBRARIES-Python-/deployments',
#   'description': None,
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/ladazolotuhina/-LIBRARIES-Python-/downloads',
#   'events_url': 'https://api.github.com/repos/ladazolotuhina/-LIBRARIES-Python-/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/ladazolotuhina/-LIBRARIES-Python-/forks',
#   'full_name': 'ladazolotuhina/-LIBRARIES-Python-',
#   'git_commits_url': 'https://api.github.com/repos/ladazolotuhina/-LIBRARIES-Python-/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/ladazolotuhina/-LIBRARIES-Python-/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/ladazolotuhina/-LIBRARIES-Python-/git/tags{/sha}',
#   'git_url': 'git://github.com/ladazolotuhina/-LIBRARIES-Python-.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/ladazolotuhina/-LIBRARIES-Python-/hooks',
#   'html_url': 'https://github.com/ladazolotuhina/-LIBRARIES-Python-',
#   'id': 487601072,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/ladazolotuhina/-LIBRARIES-Python-/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/ladazolotuhina/-LIBRARIES-Python-/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/ladazolotuhina/-LIBRARIES-Python-/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/ladazolotuhina/-LIBRARIES-Python-/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/ladazolotuhina/-LIBRARIES-Python-/labels{/name}',
#   'language': None,
#   'languages_url': 'https://api.github.com/repos/ladazolotuhina/-LIBRARIES-Python-/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/ladazolotuhina/-LIBRARIES-Python-/merges',
#   'milestones_url': 'https://api.github.com/repos/ladazolotuhina/-LIBRARIES-Python-/milestones{/number}',
#   'mirror_url': None,
#   'name': '-LIBRARIES-Python-',
#   'node_id': 'R_kgDOHRAzsA',
#   'notifications_url': 'https://api.github.com/repos/ladazolotuhina/-LIBRARIES-Python-/notifications{?since,all,participating}',
#   'open_issues': 5,
#   'open_issues_count': 5,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/93738394?v=4',
#             'events_url': 'https://api.github.com/users/ladazolotuhina/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/ladazolotuhina/followers',
#             'following_url': 'https://api.github.com/users/ladazolotuhina/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/ladazolotuhina/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/ladazolotuhina',
#             'id': 93738394,
#             'login': 'ladazolotuhina',
#             'node_id': 'U_kgDOBZZVmg',
#             'organizations_url': 'https://api.github.com/users/ladazolotuhina/orgs',
#             'received_events_url': 'https://api.github.com/users/ladazolotuhina/received_events',
#             'repos_url': 'https://api.github.com/users/ladazolotuhina/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/ladazolotuhina/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/ladazolotuhina/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/ladazolotuhina'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/ladazolotuhina/-LIBRARIES-Python-/pulls{/number}',
#   'pushed_at': '2022-06-22T18:55:50Z',
#   'releases_url': 'https://api.github.com/repos/ladazolotuhina/-LIBRARIES-Python-/releases{/id}',
#   'size': 497,
#   'ssh_url': 'git@github.com:ladazolotuhina/-LIBRARIES-Python-.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/ladazolotuhina/-LIBRARIES-Python-/stargazers',
#   'statuses_url': 'https://api.github.com/repos/ladazolotuhina/-LIBRARIES-Python-/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/ladazolotuhina/-LIBRARIES-Python-/subscribers',
#   'subscription_url': 'https://api.github.com/repos/ladazolotuhina/-LIBRARIES-Python-/subscription',
#   'svn_url': 'https://github.com/ladazolotuhina/-LIBRARIES-Python-',
#   'tags_url': 'https://api.github.com/repos/ladazolotuhina/-LIBRARIES-Python-/tags',
#   'teams_url': 'https://api.github.com/repos/ladazolotuhina/-LIBRARIES-Python-/teams',
#   'topics': [],
#   'trees_url': 'https://api.github.com/repos/ladazolotuhina/-LIBRARIES-Python-/git/trees{/sha}',
#   'updated_at': '2022-05-01T17:36:52Z',
#   'url': 'https://api.github.com/repos/ladazolotuhina/-LIBRARIES-Python-',
#   'visibility': 'public',
#   'watchers': 0,
#   'watchers_count': 0,
#   'web_commit_signoff_required': False},
#  {'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/ladazolotuhina/Introdution_to_HMath/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/ladazolotuhina/Introdution_to_HMath/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/ladazolotuhina/Introdution_to_HMath/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/ladazolotuhina/Introdution_to_HMath/branches{/branch}',
#   'clone_url': 'https://github.com/ladazolotuhina/Introdution_to_HMath.git',
#   'collaborators_url': 'https://api.github.com/repos/ladazolotuhina/Introdution_to_HMath/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/ladazolotuhina/Introdution_to_HMath/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/ladazolotuhina/Introdution_to_HMath/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/ladazolotuhina/Introdution_to_HMath/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/ladazolotuhina/Introdution_to_HMath/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/ladazolotuhina/Introdution_to_HMath/contributors',
#   'created_at': '2022-08-13T09:31:52Z',
#   'default_branch': 'main',
#   'deployments_url': 'https://api.github.com/repos/ladazolotuhina/Introdution_to_HMath/deployments',
#   'description': None,
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/ladazolotuhina/Introdution_to_HMath/downloads',
#   'events_url': 'https://api.github.com/repos/ladazolotuhina/Introdution_to_HMath/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/ladazolotuhina/Introdution_to_HMath/forks',
#   'full_name': 'ladazolotuhina/Introdution_to_HMath',
#   'git_commits_url': 'https://api.github.com/repos/ladazolotuhina/Introdution_to_HMath/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/ladazolotuhina/Introdution_to_HMath/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/ladazolotuhina/Introdution_to_HMath/git/tags{/sha}',
#   'git_url': 'git://github.com/ladazolotuhina/Introdution_to_HMath.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/ladazolotuhina/Introdution_to_HMath/hooks',
#   'html_url': 'https://github.com/ladazolotuhina/Introdution_to_HMath',
#   'id': 524355369,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/ladazolotuhina/Introdution_to_HMath/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/ladazolotuhina/Introdution_to_HMath/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/ladazolotuhina/Introdution_to_HMath/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/ladazolotuhina/Introdution_to_HMath/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/ladazolotuhina/Introdution_to_HMath/labels{/name}',
#   'language': None,
#   'languages_url': 'https://api.github.com/repos/ladazolotuhina/Introdution_to_HMath/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/ladazolotuhina/Introdution_to_HMath/merges',
#   'milestones_url': 'https://api.github.com/repos/ladazolotuhina/Introdution_to_HMath/milestones{/number}',
#   'mirror_url': None,
#   'name': 'Introdution_to_HMath',
#   'node_id': 'R_kgDOH0EHKQ',
#   'notifications_url': 'https://api.github.com/repos/ladazolotuhina/Introdution_to_HMath/notifications{?since,all,participating}',
#   'open_issues': 3,
#   'open_issues_count': 3,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/93738394?v=4',
#             'events_url': 'https://api.github.com/users/ladazolotuhina/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/ladazolotuhina/followers',
#             'following_url': 'https://api.github.com/users/ladazolotuhina/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/ladazolotuhina/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/ladazolotuhina',
#             'id': 93738394,
#             'login': 'ladazolotuhina',
#             'node_id': 'U_kgDOBZZVmg',
#             'organizations_url': 'https://api.github.com/users/ladazolotuhina/orgs',
#             'received_events_url': 'https://api.github.com/users/ladazolotuhina/received_events',
#             'repos_url': 'https://api.github.com/users/ladazolotuhina/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/ladazolotuhina/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/ladazolotuhina/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/ladazolotuhina'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/ladazolotuhina/Introdution_to_HMath/pulls{/number}',
#   'pushed_at': '2022-08-29T19:06:54Z',
#   'releases_url': 'https://api.github.com/repos/ladazolotuhina/Introdution_to_HMath/releases{/id}',
#   'size': 1265,
#   'ssh_url': 'git@github.com:ladazolotuhina/Introdution_to_HMath.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/ladazolotuhina/Introdution_to_HMath/stargazers',
#   'statuses_url': 'https://api.github.com/repos/ladazolotuhina/Introdution_to_HMath/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/ladazolotuhina/Introdution_to_HMath/subscribers',
#   'subscription_url': 'https://api.github.com/repos/ladazolotuhina/Introdution_to_HMath/subscription',
#   'svn_url': 'https://github.com/ladazolotuhina/Introdution_to_HMath',
#   'tags_url': 'https://api.github.com/repos/ladazolotuhina/Introdution_to_HMath/tags',
#   'teams_url': 'https://api.github.com/repos/ladazolotuhina/Introdution_to_HMath/teams',
#   'topics': [],
#   'trees_url': 'https://api.github.com/repos/ladazolotuhina/Introdution_to_HMath/git/trees{/sha}',
#   'updated_at': '2022-08-13T09:31:52Z',
#   'url': 'https://api.github.com/repos/ladazolotuhina/Introdution_to_HMath',
#   'visibility': 'public',
#   'watchers': 0,
#   'watchers_count': 0,
#   'web_commit_signoff_required': False},
#  {'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework/branches{/branch}',
#   'clone_url': 'https://github.com/ladazolotuhina/pythonbase-homework.git',
#   'collaborators_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework/contributors',
#   'created_at': '2021-11-12T11:12:32Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework/deployments',
#   'description': None,
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework/downloads',
#   'events_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework/forks',
#   'full_name': 'ladazolotuhina/pythonbase-homework',
#   'git_commits_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework/git/tags{/sha}',
#   'git_url': 'git://github.com/ladazolotuhina/pythonbase-homework.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework/hooks',
#   'html_url': 'https://github.com/ladazolotuhina/pythonbase-homework',
#   'id': 427330851,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework/labels{/name}',
#   'language': 'Python',
#   'languages_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework/merges',
#   'milestones_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework/milestones{/number}',
#   'mirror_url': None,
#   'name': 'pythonbase-homework',
#   'node_id': 'R_kgDOGXiNIw',
#   'notifications_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework/notifications{?since,all,participating}',
#   'open_issues': 7,
#   'open_issues_count': 7,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/93738394?v=4',
#             'events_url': 'https://api.github.com/users/ladazolotuhina/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/ladazolotuhina/followers',
#             'following_url': 'https://api.github.com/users/ladazolotuhina/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/ladazolotuhina/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/ladazolotuhina',
#             'id': 93738394,
#             'login': 'ladazolotuhina',
#             'node_id': 'U_kgDOBZZVmg',
#             'organizations_url': 'https://api.github.com/users/ladazolotuhina/orgs',
#             'received_events_url': 'https://api.github.com/users/ladazolotuhina/received_events',
#             'repos_url': 'https://api.github.com/users/ladazolotuhina/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/ladazolotuhina/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/ladazolotuhina/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/ladazolotuhina'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework/pulls{/number}',
#   'pushed_at': '2022-05-22T07:52:36Z',
#   'releases_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework/releases{/id}',
#   'size': 30,
#   'ssh_url': 'git@github.com:ladazolotuhina/pythonbase-homework.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework/stargazers',
#   'statuses_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework/subscribers',
#   'subscription_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework/subscription',
#   'svn_url': 'https://github.com/ladazolotuhina/pythonbase-homework',
#   'tags_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework/tags',
#   'teams_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework/teams',
#   'topics': [],
#   'trees_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework/git/trees{/sha}',
#   'updated_at': '2022-05-22T07:52:39Z',
#   'url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework',
#   'visibility': 'public',
#   'watchers': 0,
#   'watchers_count': 0,
#   'web_commit_signoff_required': False},
#  {'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework1/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework1/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework1/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework1/branches{/branch}',
#   'clone_url': 'https://github.com/ladazolotuhina/pythonbase-homework1.git',
#   'collaborators_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework1/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework1/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework1/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework1/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework1/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework1/contributors',
#   'created_at': '2021-11-04T20:25:52Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework1/deployments',
#   'description': None,
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework1/downloads',
#   'events_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework1/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework1/forks',
#   'full_name': 'ladazolotuhina/pythonbase-homework1',
#   'git_commits_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework1/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework1/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework1/git/tags{/sha}',
#   'git_url': 'git://github.com/ladazolotuhina/pythonbase-homework1.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework1/hooks',
#   'html_url': 'https://github.com/ladazolotuhina/pythonbase-homework1',
#   'id': 424730785,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework1/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework1/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework1/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework1/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework1/labels{/name}',
#   'language': 'Python',
#   'languages_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework1/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework1/merges',
#   'milestones_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework1/milestones{/number}',
#   'mirror_url': None,
#   'name': 'pythonbase-homework1',
#   'node_id': 'R_kgDOGVDgoQ',
#   'notifications_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework1/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/93738394?v=4',
#             'events_url': 'https://api.github.com/users/ladazolotuhina/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/ladazolotuhina/followers',
#             'following_url': 'https://api.github.com/users/ladazolotuhina/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/ladazolotuhina/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/ladazolotuhina',
#             'id': 93738394,
#             'login': 'ladazolotuhina',
#             'node_id': 'U_kgDOBZZVmg',
#             'organizations_url': 'https://api.github.com/users/ladazolotuhina/orgs',
#             'received_events_url': 'https://api.github.com/users/ladazolotuhina/received_events',
#             'repos_url': 'https://api.github.com/users/ladazolotuhina/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/ladazolotuhina/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/ladazolotuhina/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/ladazolotuhina'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework1/pulls{/number}',
#   'pushed_at': '2021-11-12T11:07:32Z',
#   'releases_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework1/releases{/id}',
#   'size': 3,
#   'ssh_url': 'git@github.com:ladazolotuhina/pythonbase-homework1.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework1/stargazers',
#   'statuses_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework1/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework1/subscribers',
#   'subscription_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework1/subscription',
#   'svn_url': 'https://github.com/ladazolotuhina/pythonbase-homework1',
#   'tags_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework1/tags',
#   'teams_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework1/teams',
#   'topics': [],
#   'trees_url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework1/git/trees{/sha}',
#   'updated_at': '2021-11-12T11:07:24Z',
#   'url': 'https://api.github.com/repos/ladazolotuhina/pythonbase-homework1',
#   'visibility': 'public',
#   'watchers': 0,
#   'watchers_count': 0,
#   'web_commit_signoff_required': False}]

# %%
print('Список моих репозиториев:\n')
for i in Res.json():
    print(i['name'])
# Out:
# Список моих репозиториев:
#
# -LIBRARIES-Python-
# Introdution_to_HMath
# pythonbase-homework
# pythonbase-homework1

# %%
for i in Res.json():
    print(i['full_name'])
# Out:
# ladazolotuhina/-LIBRARIES-Python-
# ladazolotuhina/Introdution_to_HMath
# ladazolotuhina/pythonbase-homework
# ladazolotuhina/pythonbase-homework1

# %%
with open('data', 'w') as f:
    json.dump(Res.json(), f)
